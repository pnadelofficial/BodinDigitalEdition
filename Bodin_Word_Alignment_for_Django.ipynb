# %% [markdown]
# # Imports and Installations

# %%
# !pip install transformers==3.1.0
# !pip install python-docx
# !pip install stanza
# !pip install awesome-align
# !pip install laserembeddings
# !python -m laserembeddings download-models

import sys
import torch
import transformers
import itertools
import docx
import re
from bs4 import BeautifulSoup
import stanza 
import pandas as pd
import numpy as np
import json
import re 
import nltk
from nltk.tokenize import sent_tokenize
from laserembeddings import Laser

laser = Laser()
nltk.download('punkt')
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-multilingual-cased')
# Out:
# Collecting transformers==3.1.0
#   Downloading transformers-3.1.0-py3-none-any.whl (884 kB)
#      |████████████████████████████████| 884 kB 4.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (21.3)
# Collecting tokenizers==0.8.1.rc2
#   Downloading tokenizers-0.8.1rc2-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 61.0 MB/s
# Collecting sentencepiece!=0.1.92
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 44.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (3.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (4.63.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.1.0) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 61.0 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.1.0) (3.0.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.1.0) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.1.0) (1.1.0)
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.49 sentencepiece-0.1.96 tokenizers-0.8.1rc2 transformers-3.1.0
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 4.3 MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx) (4.2.6)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=98f1eaf7d8ffaa3471d921c04cbb28f8d0e66c08a9afb545c8fa0cf1ab89c80e
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Collecting stanza
#   Downloading stanza-1.3.0-py3-none-any.whl (432 kB)
#      |████████████████████████████████| 432 kB 4.4 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.21.5)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.10.0+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.63.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 40.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.10.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=1610d20adece413edefc395ead8fc8029d0357a1741844006c0d85dd7a74f003
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji, stanza
# Successfully installed emoji-1.7.0 stanza-1.3.0
# Collecting awesome-align
#   Downloading awesome_align-0.1.7-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 3.0 MB/s
# Requirement already satisfied: tokenizers>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from awesome-align) (0.8.1rc2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from awesome-align) (2.23.0)
# Collecting boto3
#   Downloading boto3-1.21.20-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 24.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from awesome-align) (4.63.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from awesome-align) (1.21.5)
# Requirement already satisfied: torch>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from awesome-align) (1.10.0+cu111)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from awesome-align) (3.6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.2.0->awesome-align) (3.10.0.2)
# Collecting botocore<1.25.0,>=1.24.20
#   Downloading botocore-1.24.20-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 57.3 MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.0 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.25.0,>=1.24.20->boto3->awesome-align) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 49.4 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.25.0,>=1.24.20->boto3->awesome-align) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->awesome-align) (3.0.4)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 59.0 MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->awesome-align) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->awesome-align) (2021.10.8)
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3, awesome-align
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed awesome-align-0.1.7 boto3-1.21.20 botocore-1.24.20 jmespath-0.10.0 s3transfer-0.5.2 urllib3-1.25.11
# Collecting laserembeddings
#   Downloading laserembeddings-1.1.2-py3-none-any.whl (13 kB)
# Requirement already satisfied: torch<2.0.0,>=1.0.1.post2 in /usr/local/lib/python3.7/dist-packages (from laserembeddings) (1.10.0+cu111)
# Requirement already satisfied: numpy<2.0.0,>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from laserembeddings) (1.21.5)
# Collecting sacremoses==0.0.35
#   Downloading sacremoses-0.0.35.tar.gz (859 kB)
#      |████████████████████████████████| 859 kB 4.3 MB/s
# Collecting subword-nmt<0.4.0,>=0.3.6
#   Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Collecting transliterate==1.10.2
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses==0.0.35->laserembeddings) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sacremoses==0.0.35->laserembeddings) (4.63.0)
# Collecting mock
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch<2.0.0,>=1.0.1.post2->laserembeddings) (3.10.0.2)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-py3-none-any.whl size=883989 sha256=33237a8dfdff66b080792e0fd097891117693242db0973f052e4c999c0adad47
#   Stored in directory: /root/.cache/pip/wheels/d1/ff/0e/e00ff1e22100702ac8b24e709551ae0fb29db9ffc843510a64
# Successfully built sacremoses
# Installing collected packages: mock, transliterate, subword-nmt, sacremoses, laserembeddings
#   Attempting uninstall: sacremoses
#     Found existing installation: sacremoses 0.0.49
#     Uninstalling sacremoses-0.0.49:
#       Successfully uninstalled sacremoses-0.0.49
# Successfully installed laserembeddings-1.1.2 mock-4.0.3 sacremoses-0.0.35 subword-nmt-0.3.8 transliterate-1.10.2
# Downloading models into /usr/local/lib/python3.7/dist-packages/laserembeddings/data
#
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fcodes
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fvocab
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/bilstm.93langs.2018-12-26.pt
#
# ✨ You're all set!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Downloading:   0%|          | 0.00/996k [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
stanza.download('en')
stanza.download('fr')
stanza.download('la')

nlp_eng = stanza.Pipeline('en')
nlp_fra = stanza.Pipeline('fr')
nlp_la = stanza.Pipeline('la')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-03-15 15:09:32 INFO: Downloading default packages for language: en (English)...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-03-15 15:09:47 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-03-15 15:09:47 INFO: Downloading default packages for language: fr (French)...
# Downloading https://huggingface.co/stanfordnlp/stanza-fr/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-03-15 15:10:03 INFO: Finished downloading models and saved to /root/stanza_resources.
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-03-15 15:10:03 INFO: Downloading default packages for language: la (Latin)...
# Downloading https://huggingface.co/stanfordnlp/stanza-la/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-03-15 15:10:10 INFO: Finished downloading models and saved to /root/stanza_resources.
# 2022-03-15 15:10:10 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-03-15 15:10:10 INFO: Use device: cpu
# 2022-03-15 15:10:10 INFO: Loading: tokenize
# 2022-03-15 15:10:10 INFO: Loading: pos
# 2022-03-15 15:10:10 INFO: Loading: lemma
# 2022-03-15 15:10:10 INFO: Loading: depparse
# 2022-03-15 15:10:11 INFO: Loading: sentiment
# 2022-03-15 15:10:11 INFO: Loading: constituency
# 2022-03-15 15:10:12 INFO: Loading: ner
# 2022-03-15 15:10:14 INFO: Done loading processors!
# 2022-03-15 15:10:14 INFO: Loading these models for language: fr (French):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# | depparse  | gsd     |
# | ner       | wikiner |
# =======================
#
# 2022-03-15 15:10:14 INFO: Use device: cpu
# 2022-03-15 15:10:14 INFO: Loading: tokenize
# 2022-03-15 15:10:14 INFO: Loading: mwt
# 2022-03-15 15:10:14 INFO: Loading: pos
# 2022-03-15 15:10:14 INFO: Loading: lemma
# 2022-03-15 15:10:14 INFO: Loading: depparse
# 2022-03-15 15:10:15 INFO: Loading: ner
# 2022-03-15 15:10:17 INFO: Done loading processors!
# 2022-03-15 15:10:17 INFO: Loading these models for language: la (Latin):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ittb    |
# | pos       | ittb    |
# | lemma     | ittb    |
# | depparse  | ittb    |
# =======================
#
# 2022-03-15 15:10:17 INFO: Use device: cpu
# 2022-03-15 15:10:17 INFO: Loading: tokenize
# 2022-03-15 15:10:17 INFO: Loading: pos
# 2022-03-15 15:10:17 INFO: Loading: lemma
# 2022-03-15 15:10:17 INFO: Loading: depparse
# 2022-03-15 15:10:18 INFO: Done loading processors!

# %% [markdown]
# # Pre-processing

# %%
def chapFromTEI(soup):
  chap = {}

  for note in soup.find_all('note'):
    note.decompose() 
  # for head in soup.find_all('head'):
  #   head.decompose() Why no head?? 
  for i in range(len(soup.find_all('div', attrs={"type": "textpart", "subtype": "chapter"}))):
    for p in soup.find_all('div', attrs={"type": "textpart", "subtype": "chapter"})[i].find_all('p'):
      text = ''
      if f'Chapter {i+1}' in chap:
        chap[f'Chapter {i+1}'] = chap[f'Chapter {i+1}'] + p.get_text().replace('\n','').replace('                     ', ' ').replace('                  ', ' ').replace('     ', ' ').replace('    ', ' ')
      else:
        chap[f'Chapter {i+1}'] = p.get_text().replace('\n','').replace('                     ', ' ').replace('                  ', ' ').replace('     ', ' ').replace('    ', ' ')

  df = pd.DataFrame.from_dict(chap, orient='index')
  return df

# %% [markdown]
# ## French

# %%
french_xml = open('/content/bodin.livrep.perseus-fre1.xml')
french_soup = BeautifulSoup(french_xml, 'lxml')

# %%
french_df = chapFromTEI(french_soup)

# %%
with open('dev.fr', "w") as frb:
  for line in french_df[0][0].split('.'):
    frb.write(line + '.\n')

# %% [markdown]
# ## English

# %%
english_xml = open('/content/bodin.livrep.perseus-eng1.xml')
english_soup = BeautifulSoup(english_xml, 'lxml')

# %%
english_df = chapFromTEI(english_soup)

# %%
with open('dev.en', "w") as erb:
  for line in english_df[0][0].split('.'):
    erb.write(line + '.\n')

# %% [markdown]
# ## Latin

# %%
import re
doc = docx.Document('full book of latin.docx')

bodin_la = []

for p in doc.paragraphs:
  if (('Page' not in p.text) and ('PAGE' not in p.text) and (not p.text.isnumeric())):
    bodin_la.append(p.text)
   
bodin_la_string = ('\n'.join(bodin_la)).replace("\n","").replace("\t","")
x = re.split("<HI>[\s\S]*?<\/HI>",bodin_la_string)

# y = re.search("<DIV1.+",x[1].split("</HEAD>")[1])
# ch_1_text = x[1].split("</HEAD>")[1][0:y.start()]

# text_clean = re.sub("\[(.*?)\]", ' ', ch_1_text).replace("  ", "").replace("- -", " ")
# lat_soup = BeautifulSoup(text_clean, 'lxml')
# for note in lat_soup.find_all('note'):
#   note.decompose()
# lat_soup.get_text()
lat_dict = {}
for index, caput in enumerate(x[1:]):

  title = caput.split("</HEAD>")[0].replace("?","").strip()

  y = re.search("<DIV1.+",caput.split("</HEAD>")[1])
  if y:
    ch_text = caput.split("</HEAD>")[1][0:y.start()]
    text_clean = re.sub("\[(.*?)\]", ' ', ch_text).replace(",",",  ").replace("  ", "").replace("- -", " ").replace(":", ": ")
    lat_soup = BeautifulSoup(text_clean, 'lxml')
    for note in lat_soup.find_all('note'):
      note.decompose()
    text_final = lat_soup.get_text()
  else:
    ch_text = caput.split("</HEAD>")[1]
    text_clean = re.sub("\[(.*?)\]", ' ', ch_text).replace(",",", ").replace("  ", "").replace("- -", " ").replace(":", ": ")
    lat_soup = BeautifulSoup(text_clean, 'lxml')
    for note in lat_soup.find_all('note'):
      note.decompose()
    text_final = lat_soup.get_text()
  lat_dict[f'Chapter {index+1}'] = text_final.strip()

latin_df = pd.DataFrame.from_dict(lat_dict, orient='index')
split_lines = re.findall("[A-Z].+?\.", latin_df[0][0])#############COMEBACK  [f(x) for x in sequence if condition]
split_lines = [' '.join([split_lines[i], split_lines[i+1]]) if len(split_lines[i].split())<4 else split_lines[i] for i in range(len(split_lines))]

# %%
with open('dev.la', "w") as enb:
  for line in split_lines:
    enb.write(line + '\n')

# %% [markdown]
# # Sentence-level (Vecalign)

# %%
# !git clone https://github.com/thompsonb/vecalign
# Out:
# Cloning into 'vecalign'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 47 (delta 0), reused 1 (delta 0), pack-reused 44
# Unpacking objects: 100% (47/47), done.
# Checking out files: 100% (40/40), done.

# %%
# !/content/vecalign/overlap.py -i /content/dev.fr -o overlaps.fr -n 10
# !/content/vecalign/overlap.py -i /content/dev.en -o overlaps.en -n 10
# !/content/vecalign/overlap.py -i /content/dev.la -o overlaps.la -n 10

# %%
# with open('/content/overlaps.fr', 'r') as frOver:
#   fr_overlap = frOver.readlines() 

# with open('/content/overlaps.en', 'r') as enOver:
#   en_overlap = enOver.readlines()

# with open('/content/overlaps.la','r') as laOver:
#   la_overlap = laOver.readlines()

# %%
# fr_embeddings = laser.embed_sentences(fr_overlap,lang='fr')
# en_embeddings = laser.embed_sentences(en_overlap,lang='la')
# la_embeddings = laser.embed_sentences(la_overlap,lang='la')

# with open('overlaps.fr.emb','wb') as fEmb:
#   for line in fr_embeddings:
#     fEmb.write(bytes(line))

# with open('overlaps.en.emb','wb') as eEmb:
#   for line in en_embeddings:
#     eEmb.write(bytes(line))   

# with open('overlaps.la.emb', 'wb') as lEmb:
#   for line in la_embeddings:
#     lEmb.write(bytes(line))

# %%
# old_stdout = sys.stdout

# %% [markdown]
# ## Fre -> Eng

# %%
def createAlignedUnalignedFrEn(log_file):
  aligned_sent = []

  for line in log_file:
    for pair in re.findall('\[..*\]',line):
      tup_pair = []
      for item in pair.split(':'):
        if ',' in item:
          many = []
          for num in item.split(','):
            many.append(int(num.strip().replace('[','').replace(']','')))
          tup_pair.append(tuple(many))
        else:
          if item != '[]':
            tup_pair.append(int(item.replace('[','').replace(']','')))
          else:
            tup_pair.append('None')
      aligned_sent.append(tuple(tup_pair))

  unaligned_sent_x = []
  unaligned_sent_y = []

  for tup in aligned_sent:
    if tup[1] == 'None':
      unaligned_sent_x.append(tup[0])
      #aligned_sent.remove(tup)
    elif tup[0] == 'None':
      unaligned_sent_y.append(tup[1])
      #aligned_sent.remove(tup)
  
  for tup in aligned_sent:
    if ((tup[0] == 'None') or (tup[1] == 'None')):
      aligned_sent.remove(tup)

  aligned_sent = aligned_sent[:8] + aligned_sent[9:] ## NEED BETTER METHOD WILL NOT WORK FOR LATIN

  return aligned_sent, unaligned_sent_x, unaligned_sent_y

# %%
# sys.stdout = open('FrEnVecalignLog.txt','wt')

# !/content/vecalign/vecalign.py --src /content/dev.fr --tgt /content/dev.en \
# --src_embed /content/overlaps.fr /content/overlaps.fr.emb \
# --tgt_embed /content/overlaps.en /content/overlaps.en.emb

# sys.stdout.close()
# sys.stdout = old_stdout

# %%
# with open('/content/FrEnVecalignLog.txt','r') as fren_val:
#   fren_vec_log = fren_val.readlines()

# %%
# fren_aligned_sent, fren_unaligned, eng_unaligned = createAlignedUnalignedFrEn(fren_vec_log)

# %%
def FrEnalignedIndiciesJSON(aligned_sent, chapter_number):
  ## FOR JS -- Sentence View
  aligned_for_json = [] 
  for tup in aligned_sent:
    new_tup = []
    if type(tup[0]) == tuple:
      res = ''
      for i in tup[0]:
        res = res+str(i)
      new_tup.append(res)
      if type(tup[1]) == tuple:
        ult = ''
        for i in tup[1]:
          ult = ult+str(i)
        new_tup.append(ult)
      else:
        new_tup.append(str(tup[1]))
      aligned_for_json.append(tuple(new_tup))
    else:
      new_tup.append(str(tup[0]))
      if type(tup[1]) == tuple:
        ult = ''
        for i in tup[1]:
          ult = ult+str(i)
        new_tup.append(ult)
      else:
        new_tup.append(str(tup[1]))
      aligned_for_json.append(tuple(new_tup))

  with open(f'FrEn_aligned_indices{chapter_number}.json', 'w', encoding='utf-8') as json_file:
    json.dump(aligned_for_json, json_file, ensure_ascii=False, indent=4)

# %%
# FrEnalignedIndiciesJSON(fren_aligned_sent)

# %% [markdown]
# ## Fre -> Lat

# %%
def createAlignedUnalignedFrLa(log_file):
  aligned_sent = []

  for line in log_file:
    for pair in re.findall('\[..*\]',line):
      tup_pair = []
      for item in pair.split(':'):
        if ',' in item:
          many = []
          for num in item.split(','):
            many.append(int(num.strip().replace('[','').replace(']','')))
          tup_pair.append(tuple(many))
        else:
          if item != '[]':
            tup_pair.append(int(item.replace('[','').replace(']','')))
          else:
            tup_pair.append('None')
      aligned_sent.append(tuple(tup_pair))

  unaligned_sent_x = []
  unaligned_sent_y = []

  for tup in aligned_sent:
    if tup[1] == 'None':
      unaligned_sent_x.append(tup[0])
      #aligned_sent.remove(tup)
    elif tup[0] == 'None':
      unaligned_sent_y.append(tup[1])
      #aligned_sent.remove(tup)
  
  for tup in aligned_sent:
    if ((tup[0] == 'None') or (tup[1] == 'None')):
      aligned_sent.remove(tup)

  return aligned_sent, unaligned_sent_x, unaligned_sent_y

# %%
# sys.stdout = open('FrLaVecalignLog.txt','wt')

# !/content/vecalign/vecalign.py --src /content/dev.fr --tgt /content/dev.la \
# --src_embed /content/overlaps.fr /content/overlaps.fr.emb \
# --tgt_embed /content/overlaps.la /content/overlaps.la.emb

# sys.stdout.close()
# sys.stdout = old_stdout

# %%
# with open('/content/FrLaVecalignLog.txt','r') as frla_val:
#   frla_vec_log = frla_val.readlines()

# %%
# frla_aligned_sent, frla_unaligned, lat_unaligned = createAlignedUnalignedFrLa(frla_vec_log)

# %%
def FrLaalignedIndiciesJSON(aligned_sent, chapter_number):
  ## FOR JS -- Sentence View
  aligned_for_json = [] 
  for tup in aligned_sent:
    new_tup = []
    if type(tup[0]) == tuple:
      res = ''
      for i in tup[0]:
        res = res+str(i)
      new_tup.append(res)
      if type(tup[1]) == tuple:
        ult = ''
        for i in tup[1]:
          ult = ult+str(i)
        new_tup.append(ult)
      else:
        new_tup.append(str(tup[1]))
      aligned_for_json.append(tuple(new_tup))
    else:
      new_tup.append(str(tup[0]))
      if type(tup[1]) == tuple:
        ult = ''
        for i in tup[1]:
          ult = ult+str(i)
        new_tup.append(ult)
      else:
        new_tup.append(str(tup[1]))
      aligned_for_json.append(tuple(new_tup))

  with open(f'FrLa_aligned_indices.json{chapter_number}', 'w', encoding='utf-8') as json_file:
    json.dump(aligned_for_json, json_file, ensure_ascii=False, indent=4)

# %%
# FrLaalignedIndiciesJSON(frla_aligned_sent)

# %% [markdown]
# ## Eng -> Lat

# %%
# def createAlignedUnalignedEnLa(log_file):
#   aligned_sent = []

#   for line in log_file:
#     for pair in re.findall('\[..*\]',line):
#       tup_pair = []
#       for item in pair.split(':'):
#         if ',' in item:
#           many = []
#           for num in item.split(','):
#             many.append(int(num.strip().replace('[','').replace(']','')))
#           tup_pair.append(tuple(many))
#         else:
#           if item != '[]':
#             tup_pair.append(int(item.replace('[','').replace(']','')))
#           else:
#             tup_pair.append('None')
#       aligned_sent.append(tuple(tup_pair))

#   unaligned_sent_x = []
#   unaligned_sent_y = []

#   for tup in aligned_sent:
#     if tup[1] == 'None':
#       unaligned_sent_x.append(tup[0])
#       #aligned_sent.remove(tup)
#     elif tup[0] == 'None':
#       unaligned_sent_y.append(tup[1])
#       #aligned_sent.remove(tup)
  
#   for tup in aligned_sent:
#     if ((tup[0] == 'None') or (tup[1] == 'None')):
#       aligned_sent.remove(tup)

#   return aligned_sent, unaligned_sent_x, unaligned_sent_y

# %%
# sys.stdout = open('EnLaVecalignLog.txt','wt')

# !/content/vecalign/vecalign.py --src /content/dev.en --tgt /content/dev.la \
# --src_embed /content/overlaps.en /content/overlaps.en.emb \
# --tgt_embed /content/overlaps.la /content/overlaps.la.emb

# sys.stdout.close()
# sys.stdout = old_stdout

# %%
# with open('/content/EnLaVecalignLog.txt','r') as enla_val:
#   enla_vec_log = enla_val.readlines()

# %%
# enla_aligned_sent, enla_unaligned, laen_unaligned = createAlignedUnalignedFrLa(enla_vec_log)

# %%
# def EnLaalignedIndiciesJSON(aligned_sent):
#   ## FOR JS -- Sentence View
#   aligned_for_json = [] 
#   for tup in aligned_sent:
#     new_tup = []
#     if type(tup[0]) == tuple:
#       res = ''
#       for i in tup[0]:
#         res = res+str(i)
#       new_tup.append(res)
#       if type(tup[1]) == tuple:
#         ult = ''
#         for i in tup[1]:
#           ult = ult+str(i)
#         new_tup.append(ult)
#       else:
#         new_tup.append(str(tup[1]))
#       aligned_for_json.append(tuple(new_tup))
#     else:
#       new_tup.append(str(tup[0]))
#       if type(tup[1]) == tuple:
#         ult = ''
#         for i in tup[1]:
#           ult = ult+str(i)
#         new_tup.append(ult)
#       else:
#         new_tup.append(str(tup[1]))
#       aligned_for_json.append(tuple(new_tup))

#   with open(f'EnLa_aligned_indices.json', 'w', encoding='utf-8') as json_file:
#     json.dump(aligned_for_json, json_file, ensure_ascii=False, indent=4)

# %%
# EnLaalignedIndiciesJSON(enla_aligned_sent)

# %% [markdown]
# # Word-level (AwesomeAlign)

# %%
# with open("dev.fr", "r") as french_read:
#   french_sent = french_read.readlines()

# with open("dev.en", "r") as english_read:
#   english_sent = english_read.readlines()

# with open("dev.la", "r") as latin_read:
#   latin_sent = latin_read.readlines()

# %%
# !mkdir aligned_sentences
# !mkdir aligned_numbers
# !mkdir aligned_words

# %%
def AwesomeAlign(file, source_text_index):
  INPUT_FILE=file
  OUTPUT_FILE=f'aligned_numbers/number{source_text_index}.src-tgt.txt'
  OUTPUT_WORD_FILE=f'aligned_words/word{source_text_index}.src-tgt.txt'
  MODEL=f'/content/drive/MyDrive/models' 

  # !python /usr/local/lib/python3.7/dist-packages/awesome_align/run_align.py \
    --data_file=$INPUT_FILE \
    --output_file=$OUTPUT_FILE \
    --output_word_file=$OUTPUT_WORD_FILE \
    --model_name_or_path=$MODEL \

# %%
def formatUnalignedLineJSON(lang, lang_freq, source_text_index, lang_sent, unaligned_id, french_sent, english_sent, chap_number):
  lang_dict = {}

  if lang_sent is french_sent:
    for word in lang:
      if len(lang_freq[word]) == 1: ##if unique word in the sentence
        lang_dict[f'{word}'] = []
        lang_dict[f'{word}'].append({
          'chap_number': chap_number, 
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': int(f'{source_text_index}'),
          'unaligned_id': unaligned_id,
          'en_sent_aligned': None,
          'la_sent_aligned': None,
          'align_id': f'None' 
          })
      else: ##if nonunique word in the sentence ##MUST COME BACK!!!!!!
        for index in lang_freq[word]:
          lang_dict[f'{word}{index}'] = []
          lang_dict[f'{word}{index}'].append({
            'chap_number': chap_number,
            'word_text': f'{word}',
            'word_id': int(f'{index}'),
            'sent_id': int(f'{source_text_index}'),
            'unaligned_id': unaligned_id,
            'sent_aligned': None,
            'la_sent_aligned': None,
            'align_id': f'None' 
          })
  else:
    for word in lang:
      if len(lang_freq[word]) == 1: ##if unique word in the sentence
        lang_dict[f'{word}'] = []
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': int(f'{source_text_index}'),
          'unaligned_id': unaligned_id,
          'sent_aligned': None,
          'align_id': f'None' 
          })
      else: ##if nonunique word in the sentence ##MUST COME BACK!!!!!!
        for index in lang_freq[word]:
          lang_dict[f'{word}{index}'] = []
          lang_dict[f'{word}{index}'].append({
            'chap_number': chap_number,
            'word_text': f'{word}',
            'word_id': int(f'{index}'),
            'sent_id': int(f'{source_text_index}'),
            'unaligned_id': unaligned_id,
            'sent_aligned': None,
            'align_id': f'None' 
          })

  lang_dict = sorted(lang_dict.items(), key=lambda i: i[1][0]['word_id'])

  if lang_sent is french_sent:
    for sentence in nlp_fra(" ".join(lang)).sentences: ##generalize
      for word in sentence.words:
        for key in lang_dict:
          if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
            key[1][0].update(word.to_dict())
  elif lang_sent is english_sent:
    for sentence in nlp_eng(" ".join(lang)).sentences: ##generalize
      for word in sentence.words:
        for key in lang_dict:
          if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
            key[1][0].update(word.to_dict())
  else:
    for sentence in nlp_la(" ".join(lang)).sentences: ##generalize
      for word in sentence.words:
        for key in lang_dict:
          if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
            key[1][0].update(word.to_dict())

  return lang_dict

# %% [markdown]
# ## Fre -> Eng

# %%
def fren_generateJSON(lang_sent, unaligned, aligned_sent, chapter_number, french_sent, english_sent):
  # !mkdir aligned_sentences
  # !mkdir aligned_numbers
  # !mkdir aligned_words

  dict_to_json = {}

  for index, sentence in enumerate(lang_sent):
    dict_to_json[index] = []
    if index in unaligned:
      lang_freq = {}
      lang = lang_sent[index].split(' ')
      for i, word in enumerate(lang):
        if word in lang_freq:
          lang_freq[word].append(i)
        else:
          lang_freq[word] = []
          lang_freq[word].append(i)
      lang_dict = formatUnalignedLineJSON(lang, lang_freq, index, lang_sent, index, french_sent, english_sent, chapter_number)

      dict_to_json[index].append(lang_dict)
      print(str(index)+ "/" + str(len(lang_sent)), len(dict_to_json[index]))
    else:
      if lang_sent is french_sent:
        for tup in aligned_sent: 
          if ((type(tup[0]) == int) and tup[0] == index):
            x_lang_dict = makeFrEnWordDictionary(tup, french_sent, french_sent, english_sent, aligned_sent, index, chapter_number) ##THINK ABOUT BETTER PARAMETERS
            dict_to_json[index].append(x_lang_dict)
          else:
            if ((type(tup[0]) ==  tuple) and (index in tup[0])):
              x_lang_dict = makeFrEnWordDictionary(tup, french_sent, french_sent, english_sent, aligned_sent, index, chapter_number)
              dict_to_json[index].append(x_lang_dict)
        with open(f'fren_data_stanza{chapter_number}.json', 'w', encoding='utf-8') as lang:
          json.dump(dict_to_json, lang, ensure_ascii=False, indent=4)
      else:
        for tup in aligned_sent: 
          if ((type(tup[1]) == int) and tup[1] == index):
            y_lang_dict = makeEngWordDictionary(tup, english_sent, french_sent, english_sent, aligned_sent, index, chapter_number)
            dict_to_json[index].append(y_lang_dict)
          else:
            if ((type(tup[1]) ==  tuple) and (index in tup[1])):
              y_lang_dict = makeEngWordDictionary(tup, english_sent, french_sent, english_sent, aligned_sent, index, chapter_number)
              dict_to_json[index].append(y_lang_dict)
        with open(f'en_data_stanza{chapter_number}.json', 'w', encoding='utf-8') as lang:
          json.dump(dict_to_json, lang, ensure_ascii=False, indent=4)

  # !rm -r /content/aligned_numbers*
  # !rm -r /content/aligned_sentences*
  # !rm -r /content/aligned_words*

  return dict_to_json

# %% [markdown]
# ### French

# %%
def makeFrEnWordDictionary(aligned_tup, text, french_sent, english_sent, aligned_sent, unaligned_id, chap_number):
  tup_type = type(aligned_tup[0])
  if text is french_sent:
    if (type(aligned_tup[0]) == int):
      source_text_index = aligned_tup[0]
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
    else:
      if len(aligned_tup[0]) == 2:
        source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1])
        print(str(source_text_index)+"/"+str(len(french_sent)-1))
      else:
        source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1]) + str(aligned_tup[0][2])
        print(str(source_text_index)+"/"+str(len(french_sent)-1))
  else:
    if (type(aligned_tup[1]) == int):
      source_text_index = aligned_tup[1]
      print(str(source_text_index)+"/"+str(len(english_sent)-1))
    else:
      source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1])
      print(str(source_text_index)+"/"+str(len(english_sent)-1))

  if ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == int)):
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == tuple)):
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == tuple) and (type(aligned_tup[1]) == int)):
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    src_tgt = open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  else:
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)

  align_pairs = []
  align_indices = []

  with open(f'aligned_numbers/number{source_text_index}.src-tgt.txt') as g:
    align_pairs = g.readlines()

  for pair in align_pairs:
    for p in pair.replace('  \n','').split(' '):
      tup = (int(p.split('-')[0]),int(p.split('-')[1].replace('\n', '')))
      align_indices.append(tup)
  align_indices = sorted(align_indices, key=lambda x: x[0])

  with open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt') as h:
    aligned_string = h.read()

  if type(aligned_tup[0]) == tuple:
    many = aligned_string.split('   ||| ')[0]
    
    x_lang = []
    for m in many.split('.'):
      if m in french_sent[unaligned_id]:
        for word in m.strip().split():
          x_lang.append(tokenizer.tokenize(word))
    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    aligned_indices_many = []
    for w in x_lang:
      for x in [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]:
        if w == x:
          word_index = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()].index(x)
          for key in list(dict(aligned_indices).keys()): ## CHANGE TO VALUES IN ENG/LAT
            if word_index == key:
              aligned_indices_many.append((key,list(dict(aligned_indices).values())[0])) ## CHANGE TO KEYS IN ENG/LAT

    align_words = []
    for i,j in aligned_indices_many:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', '')))

  else:
    x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]

    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    align_words = [] 
    for i,j in align_indices:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', ''))) 

  x_lang_freq = {}
  for i, word in enumerate(x_lang):
    if word in x_lang_freq:
      x_lang_freq[word].append(i)
    else:
      x_lang_freq[word] = []
      x_lang_freq[word].append(i)

  x_lang_dict = formatJSONX(x_lang, x_lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)

  return x_lang_dict

# %%
def formatJSONX(lang, lang_freq, align_words, source_text_index, aligned_sent,unaligned_id, tup_type, chap_number):
  lang_dict = {}

  if (((len(str(source_text_index)) == 2) or (len(str(source_text_index)) == 3)) and (tup_type == tuple)):  ## two characters + len == 2 
    org_tup = tuple([int(n) for n in re.findall('.', str(source_text_index))])
    org_indx = list(zip(*aligned_sent))[0].index(org_tup)
    org_tgt = list(zip(*aligned_sent))[1][org_indx]
    sent_aligned = org_tgt 
  else:
    if len(re.findall('..', str(source_text_index))) > 1:
      org_tup = tuple([int(n) for n in re.findall('..', str(source_text_index))])
      org_indx = list(zip(*aligned_sent))[0].index(org_tup)
      org_tgt = list(zip(*aligned_sent))[1][org_indx]
      if type(org_tgt) == tuple:
        sent_aligned = ''
        for i in org_tgt:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = org_tgt
    else:
      plchldr_indx = list(zip(*aligned_sent))[0].index(source_text_index)
      plchldr = list(zip(*aligned_sent))[1][plchldr_indx]
      if type(plchldr) == tuple:
        sent_aligned = ''
        for i in plchldr:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = plchldr

  for word in lang:
    if len(lang_freq[word]) == 1: ##if unique word in the sentence
      lang_dict[f'{word}'] = [] 
      if word in list(dict(align_words).keys()):
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'en_sent_aligned': sent_aligned
          # 'align_id': f'{list(dict(align_words).keys()).index(word)}' 
        })
      else:
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'en_sent_aligned': sent_aligned 
          # 'align_id': f'None' 
        })
    else: ##if nonunique word in the sentence
      for index in lang_freq[word]:
        lang_dict[f'{word}{index}'] = []
        lang_dict[f'{word}{index}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{index}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'en_sent_aligned': sent_aligned
          # 'align_id': f'None' 
        })

  lang_dict = sorted(lang_dict.items(), key=lambda i: i[1][0]['word_id'])

  for sentence in nlp_fra(" ".join(lang)).sentences:
    for word in sentence.words:
      for key in lang_dict:
        if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
          key[1][0].update(word.to_dict())

  return lang_dict

# %%
# fren_dict = fren_generateJSON(french_sent, fren_unaligned, fren_aligned_sent)

# %% [markdown]
# ### English

# %%
def makeEngWordDictionary(aligned_tup, text, french_sent, english_sent, aligned_sent, unaligned_id, chap_number):
  tup_type = type(aligned_tup[1])
  if text is french_sent:
    if (type(aligned_tup[0]) == int):
      source_text_index = aligned_tup[0]
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
    else:
      source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1])
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
  else:
    if (type(aligned_tup[1]) == int):
      source_text_index = aligned_tup[1]
      print(str(source_text_index)+"/"+str(len(english_sent)-1))
    else:
      if len(aligned_tup[1]) == 2:
        source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1])
      else:
        source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1]) + str(aligned_tup[1][2])
      print(str(source_text_index)+"/"+str(len(english_sent)-1))
    
  if ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == int)):
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == tuple)):
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == tuple) and (type(aligned_tup[1]) == int)):
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    src_tgt = open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  else:
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)

  align_pairs = []
  align_indices = []

  with open(f'aligned_numbers/number{source_text_index}.src-tgt.txt') as g:
    align_pairs = g.readlines()

  for pair in align_pairs:
    for p in pair.replace('  \n','').split(' '):
      tup = (int(p.split('-')[0]),int(p.split('-')[1].replace('\n', '')))
      align_indices.append(tup)
  align_indices = sorted(align_indices, key=lambda x: x[0])

  with open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt') as h:
    aligned_string = h.read()

  if type(aligned_tup[1]) == tuple:
    many = aligned_string.split('   ||| ')[1]
    
    y_lang = []
    for m in many.split('.'):
      if m in english_sent[unaligned_id]:
        for word in m.strip().split():
          y_lang.append(tokenizer.tokenize(word))
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]
    x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]
    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    aligned_indices_many = []
    for w in y_lang:
      for x in [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]:
        if w == x:
          word_index = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()].index(x)
          for values in list(dict(aligned_indices).values()): 
            if word_index == key:
              aligned_indices_many.append((list(dict(aligned_indices).keys())[0], values)) 

    align_words = []
    for i,j in aligned_indices_many:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', '')))

  else:
    x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]

    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    align_words = [] 
    for i,j in align_indices:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', ''))) 

  y_lang_freq = {}
  for i, word in enumerate(y_lang):
    if word in y_lang_freq:
      y_lang_freq[word].append(i)
    else:
      y_lang_freq[word] = []
      y_lang_freq[word].append(i)

  y_lang_dict = formatEngJSON(y_lang, y_lang_freq, align_words, align_indices, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)

  return y_lang_dict

# %%
def formatEngJSON(lang, lang_freq, align_words, align_indices, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number):
  lang_dict = {}

  if (((len(str(source_text_index)) == 2) or (len(str(source_text_index)) == 3)) and (tup_type == tuple)):  ## two characters + len == 2 
    org_tup = tuple([int(n) for n in re.findall('.', str(source_text_index))])
    org_indx = list(zip(*aligned_sent))[1].index(org_tup)
    org_tgt = list(zip(*aligned_sent))[0][org_indx]
    sent_aligned = org_tgt 
  else:
    if len(re.findall('..', str(source_text_index))) > 1:
      org_tup = tuple([int(n) for n in re.findall('..', str(source_text_index))])
      org_indx = list(zip(*aligned_sent))[1].index(org_tup)
      org_tgt = list(zip(*aligned_sent))[0][org_indx]
      if type(org_tgt) == tuple:
        sent_aligned = ''
        for i in org_tgt:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = org_tgt
    else:
      plchldr_indx = list(zip(*aligned_sent))[1].index(source_text_index)
      plchldr = list(zip(*aligned_sent))[0][plchldr_indx]
      if type(plchldr) == tuple:
        sent_aligned = ''
        for i in plchldr:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = plchldr

  for word in lang:
    if len(lang_freq[word]) == 1: ##if unique word in the sentence
      lang_dict[f'{word}'] = [] 
      if word in list(dict(align_words).values()):
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'sent_aligned': sent_aligned,
          'align_id': f'{list(dict(align_indices).values()).index(lang.index(word))}' 
        })
      else:
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'sent_aligned': sent_aligned, 
          'align_id': f'None' 
        })
    else: ##if nonunique word in the sentence
      for i in lang_freq[word]:
        if i in list(dict(align_indices).values()):
          tup_i = list(dict(align_indices).values()).index(i) 
          tup = align_indices[tup_i]
          lang_dict[f'{word}{i}'] = []
          lang_dict[f'{word}{i}'].append({
            'chap_number': chap_number,
            'word_text': f'{word}',
            'word_id': int(f'{i}'),
            'sent_id': f'{source_text_index}', 
            'unaligned_id': unaligned_id,
            'sent_aligned': sent_aligned,
            'align_id': f'{tup[0]}' 
          })
        else:
          lang_dict[f'{word}{i}'] = []
          lang_dict[f'{word}{i}'].append({
            'chap_number': chap_number,
            'word_text': f'{word}',
            'word_id': int(f'{i}'),
            'sent_id': f'{source_text_index}',
            'unaligned_id': unaligned_id, 
            'sent_aligned': sent_aligned,
            'align_id': f'None' 
          })

  lang_dict = sorted(lang_dict.items(), key=lambda i: i[1][0]['word_id'])

  for sentence in nlp_eng(" ".join(lang)).sentences: 
    for word in sentence.words:
      for key in lang_dict:
        if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
          key[1][0].update(word.to_dict())

  return lang_dict

# %%
# fren_generateJSON(english_sent, eng_unaligned, fren_aligned_sent)

# %% [markdown]
# ## Fre -> Lat

# %%
def frla_generateJSON(lang_sent, unaligned, aligned_sent, chapter_number, french_sent, latin_sent):
  # !mkdir aligned_sentences
  # !mkdir aligned_numbers
  # !mkdir aligned_words

  dict_to_json = {}

  for index, sentence in enumerate(lang_sent):
    dict_to_json[index] = []
    if index in unaligned:
      lang_freq = {}
      lang = lang_sent[index].split(' ')
      for i, word in enumerate(lang):
        if word in lang_freq:
          lang_freq[word].append(i)
        else:
          lang_freq[word] = []
          lang_freq[word].append(i)
      lang_dict = formatUnalignedLineJSON(lang, lang_freq, index, lang_sent, index, french_sent, latin_sent, chapter_number)

      dict_to_json[index].append(lang_dict)
      print(str(index)+ "/" + str(len(lang_sent)-1), len(dict_to_json[index]))
    else:
      if lang_sent is french_sent:
        for tup in aligned_sent: 
          if ((type(tup[0]) == int) and tup[0] == index):
            x_lang_dict = makeFreWordDictionary(tup, french_sent, french_sent, latin_sent, aligned_sent, index, chapter_number) ##THINK ABOUT BETTER PARAMETERS
            dict_to_json[index].append(x_lang_dict)
          else:
            if ((type(tup[0]) ==  tuple) and (index in tup[0])):
              x_lang_dict = makeFreWordDictionary(tup, french_sent, french_sent, latin_sent, aligned_sent, index, chapter_number)
              
              dict_to_json[index].append(x_lang_dict)
        with open(f'frla_data_stanza{chapter_number}.json', 'w', encoding='utf-8') as lang:
          json.dump(dict_to_json, lang, ensure_ascii=False, indent=4)
      else:
        for tup in aligned_sent: 
          if ((type(tup[1]) == int) and tup[1] == index):
            y_lang_dict = makeLatWordDictionary(tup, latin_sent, french_sent, latin_sent, aligned_sent, index, chapter_number)
            dict_to_json[index].append(y_lang_dict)
          else:
            if ((type(tup[1]) ==  tuple) and (index in tup[1])):
              y_lang_dict = makeLatWordDictionary(tup, latin_sent, french_sent, latin_sent, aligned_sent, index, chapter_number)
              dict_to_json[index].append(y_lang_dict)
        with open(f'lat_data_stanza{chapter_number}.json', 'w', encoding='utf-8') as lang:
          json.dump(dict_to_json, lang, ensure_ascii=False, indent=4)

  # !rm -r /content/aligned_numbers*
  # !rm -r /content/aligned_sentences*
  # !rm -r /content/aligned_words*

  return dict_to_json

# %% [markdown]
# ### French

# %%
def makeFreWordDictionary(aligned_tup, text, french_sent, english_sent, aligned_sent, unaligned_id, chap_number):
  tup_type = type(aligned_tup[0])
  if text is french_sent:
    if (type(aligned_tup[0]) == int):
      source_text_index = aligned_tup[0]
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
    else:
      if len(aligned_tup[0]) == 2:
        source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1])
        print(str(source_text_index)+"/"+str(len(french_sent)-1))
      else:
        source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1]) + str(aligned_tup[0][2])
        print(str(source_text_index)+"/"+str(len(french_sent)-1))
  else:
    if (type(aligned_tup[1]) == int):
      source_text_index = aligned_tup[1]
      print(str(source_text_index)+"/"+str(len(english_sent)-1))
    else:
      source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1])
      print(str(source_text_index)+"/"+str(len(english_sent)-1))
    
  if ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == int)):
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == tuple)):
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == tuple) and (type(aligned_tup[1]) == int)):
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    src_tgt = open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+english_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  else:
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    eng_text = ''
    for i in aligned_tup[1]:
      eng_text = eng_text + english_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+eng_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)

  align_pairs = []
  align_indices = []

  with open(f'aligned_numbers/number{source_text_index}.src-tgt.txt') as g:
    align_pairs = g.readlines()

  for pair in align_pairs:
    for p in pair.replace('  \n','').split(' '):
      tup = (int(p.split('-')[0]),int(p.split('-')[1].replace('\n', '')))
      align_indices.append(tup)
  align_indices = sorted(align_indices, key=lambda x: x[0])

  with open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt') as h:
    aligned_string = h.read()

  if type(aligned_tup[0]) == tuple:
    many = aligned_string.split('   ||| ')[0]
    
    x_lang = []
    for m in many.split('.'):
      if m in french_sent[unaligned_id]:
        for word in m.strip().split():
          x_lang.append(tokenizer.tokenize(word))
    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    aligned_indices_many = []
    for w in x_lang:
      for x in [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]:
        if w == x:
          word_index = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()].index(x)
          for key in list(dict(aligned_indices).keys()): ## CHANGE TO VALUES IN ENG/LAT
            if word_index == key:
              aligned_indices_many.append((key,list(dict(aligned_indices).values())[0])) ## CHANGE TO KEYS IN ENG/LAT

    align_words = []
    for i,j in aligned_indices_many:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', '')))

  else:
    x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]

    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    align_words = [] 
    for i,j in align_indices:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', ''))) 

  x_lang_freq = {}
  for i, word in enumerate(x_lang):
    if word in x_lang_freq:
      x_lang_freq[word].append(i)
    else:
      x_lang_freq[word] = []
      x_lang_freq[word].append(i)

  x_lang_dict = formatJSONFrLa(x_lang, x_lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)

  return x_lang_dict

# %%
def formatJSONFrLa(lang, lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number):
  lang_dict = {}

  if (((len(str(source_text_index)) == 2) or (len(str(source_text_index)) == 3)) and (tup_type == tuple)):  ## two characters + len == 2 
    org_tup = tuple([int(n) for n in re.findall('.', str(source_text_index))])
    org_indx = list(zip(*aligned_sent))[0].index(org_tup)
    org_tgt = list(zip(*aligned_sent))[1][org_indx]
    sent_aligned = org_tgt 
  else:
    if len(re.findall('..', str(source_text_index))) > 1:
      org_tup = tuple([int(n) for n in re.findall('..', str(source_text_index))])
      org_indx = list(zip(*aligned_sent))[0].index(org_tup)
      org_tgt = list(zip(*aligned_sent))[1][org_indx]
      if type(org_tgt) == tuple:
        sent_aligned = ''
        for i in org_tgt:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = org_tgt
    else:
      plchldr_indx = list(zip(*aligned_sent))[0].index(source_text_index)
      plchldr = list(zip(*aligned_sent))[1][plchldr_indx]
      if type(plchldr) == tuple:
        sent_aligned = ''
        for i in plchldr:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = plchldr
    

  for word in lang:
    if len(lang_freq[word]) == 1: ##if unique word in the sentence
      lang_dict[f'{word}'] = [] 
      if word in list(dict(align_words).keys()):
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'la_sent_aligned': sent_aligned
          # 'align_id': f'{list(dict(align_words).keys()).index(word)}' 
        })
      else:
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': f'{source_text_index}',
          'unaligned_id': unaligned_id,
          'la_sent_aligned': sent_aligned 
          # 'align_id': f'None' 
        })
    else: ##if nonunique word in the sentence
      for index in lang_freq[word]:
        lang_dict[f'{word}{index}'] = []
        lang_dict[f'{word}{index}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{index}'),
          'sent_id': f'{source_text_index}', 
          'unaligned_id': unaligned_id,
          'la_sent_aligned': sent_aligned
          # 'align_id': f'None' 
        })

  lang_dict = sorted(lang_dict.items(), key=lambda i: i[1][0]['word_id'])

  for sentence in nlp_fra(" ".join(lang)).sentences:
    for word in sentence.words:
      for key in lang_dict:
        if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
          key[1][0].update(word.to_dict())

  return lang_dict

# %%
# frla_dict = frla_generateJSON(french_sent, frla_unaligned, frla_aligned_sent)

# %% [markdown]
# ### Latin

# %%
def makeLatWordDictionary(aligned_tup, text, french_sent, latin_sent, aligned_sent, unaligned_id, chap_number):
  tup_type = type(aligned_tup[1])
  if text is french_sent:
    if (type(aligned_tup[0]) == int):
      source_text_index = aligned_tup[0]
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
    else:
      source_text_index = str(aligned_tup[0][0]) + str(aligned_tup[0][1])
      print(str(source_text_index)+"/"+str(len(french_sent)-1))
  else:
    if (type(aligned_tup[1]) == int):
      source_text_index = aligned_tup[1]
      print(str(source_text_index)+"/"+str(len(latin_sent)-1))
    else:
      if len(aligned_tup[1]) == 2:
        source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1])
      else:
        source_text_index = str(aligned_tup[1][0]) + str(aligned_tup[1][1]) + str(aligned_tup[1][2])
      print(str(source_text_index)+"/"+str(len(latin_sent)-1))
    
  if ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == int)):
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+latin_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == int) and (type(aligned_tup[1]) == tuple)):
    lat_text = ''
    for i in aligned_tup[1]:
      lat_text = lat_text + latin_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(french_sent[aligned_tup[0]].replace('\n','').lstrip()+'   ||| '+lat_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  elif ((type(aligned_tup[0]) == tuple) and (type(aligned_tup[1]) == int)):
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    src_tgt = open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+latin_sent[aligned_tup[1]].replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)
  else:
    fr_text = ''
    for i in aligned_tup[0]:
      fr_text = fr_text + french_sent[i]
    lat_text = ''
    for i in aligned_tup[1]:
      lat_text = lat_text + latin_sent[i]
    open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt','w').write(fr_text.replace('\n','').lstrip()+'   ||| '+lat_text.replace('\n','').lstrip())
    AwesomeAlign(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt', source_text_index)

  align_pairs = []
  align_indices = []

  with open(f'aligned_numbers/number{source_text_index}.src-tgt.txt') as g:
    align_pairs = g.readlines()

  for pair in align_pairs:
    for p in pair.replace('  \n','').split(' '):
      tup = (int(p.split('-')[0]),int(p.split('-')[1].replace('\n', '')))
      align_indices.append(tup)
  align_indices = sorted(align_indices, key=lambda x: x[0])

  with open(f'aligned_sentences/sentence{source_text_index}.src-tgt.txt') as h:
    aligned_string = h.read()

  if type(aligned_tup[1]) == tuple:
      many = aligned_string.split('   ||| ')[1]
      
      y_lang = []
      for m in many.split('.'):
        if m in latin_sent[unaligned_id]:
          for word in m.strip().split():
            y_lang.append(tokenizer.tokenize(word))
      y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]
      x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]
      x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

      aligned_indices_many = []
      for w in y_lang:
        for x in [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]:
          if w == x:
            word_index = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()].index(x)
            for values in list(dict(aligned_indices).values()): 
              if word_index == key:
                aligned_indices_many.append((list(dict(aligned_indices).keys())[0], values)) 

      align_words = []
      for i,j in aligned_indices_many:
        align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', '')))

  else:
    x_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[0].strip().split()]
    y_lang = [tokenizer.tokenize(word) for word in aligned_string.split('   ||| ')[1].strip().split()]

    x_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in x_lang]
    y_lang = [''.join(i).replace('##','').replace('[UNK]', '') for i in y_lang]

    align_words = [] 
    for i,j in align_indices:
      align_words.append((''.join(x_lang[i]).replace('##','').replace('[UNK]', ''),''.join(y_lang[j]).replace('##','').replace('[UNK]', '')))

  y_lang_freq = {}
  for i, word in enumerate(y_lang):
    if word in y_lang_freq:
      y_lang_freq[word].append(i)
    else:
      y_lang_freq[word] = []
      y_lang_freq[word].append(i)

  y_lang_dict = formatJSONY(y_lang, y_lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)

  return y_lang_dict

# %%
def formatJSONY(lang, lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number):
  lang_dict = {}

  if (((len(str(source_text_index)) == 2) or (len(str(source_text_index)) == 3)) and (tup_type == tuple)):  ## two characters + len == 2 
    org_tup = tuple([int(n) for n in re.findall('.', str(source_text_index))])
    org_indx = list(zip(*aligned_sent))[1].index(org_tup)
    org_tgt = list(zip(*aligned_sent))[0][org_indx]
    sent_aligned = org_tgt 
  else:
    if len(re.findall('..', str(source_text_index))) > 1:
      org_tup = tuple([int(n) for n in re.findall('..', str(source_text_index))])
      org_indx = list(zip(*aligned_sent))[1].index(org_tup)
      org_tgt = list(zip(*aligned_sent))[0][org_indx]
      if type(org_tgt) == tuple:
        sent_aligned = ''
        for i in org_tgt:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = org_tgt
    else:
      plchldr_indx = list(zip(*aligned_sent))[1].index(source_text_index)
      plchldr = list(zip(*aligned_sent))[0][plchldr_indx]
      if type(plchldr) == tuple:
        sent_aligned = ''
        for i in plchldr:
          sent_aligned = sent_aligned + str(i)
      else:
        sent_aligned = plchldr

  for word in lang:
    if len(lang_freq[word]) == 1: ##if unique word in the sentence
      lang_dict[f'{word}'] = [] 
      if word in list(dict(align_words).values()):
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': int(f'{source_text_index}'),
          'unaligned_id': unaligned_id,
          'sent_aligned': sent_aligned,
          'align_id': f'{list(dict(align_words).values()).index(word)}' 
        })
      else:
        lang_dict[f'{word}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{lang.index(word)}'),
          'sent_id': int(f'{source_text_index}'),
          'unaligned_id': unaligned_id,
          'sent_aligned': sent_aligned,
          'align_id': f'None' 
        })
    else: ##if nonunique word in the sentence ##MUST COME BACK!!!!!!
      for index in lang_freq[word]:
        lang_dict[f'{word}{index}'] = []
        lang_dict[f'{word}{index}'].append({
          'chap_number': chap_number,
          'word_text': f'{word}',
          'word_id': int(f'{index}'),
          'sent_id': int(f'{source_text_index}'),
          'unaligned_id': unaligned_id,
          'sent_aligned': sent_aligned,
          'align_id': f'None' 
        })

  lang_dict = sorted(lang_dict.items(), key=lambda i: i[1][0]['word_id'])

  for sentence in nlp_la(" ".join(lang)).sentences: ## FIX
    for word in sentence.words:
      for key in lang_dict:
        if ((key[1][0]['word_text'] == word.text) or key[1][0]['word_text'][:-1] == word.text):
          key[1][0].update(word.to_dict())

  return lang_dict

# %%
# frla_generateJSON(latin_sent, lat_unaligned, frla_aligned_sent)

# %% [markdown]
# ## Merge FrEn FrLa dictionaries

# %%
# for i in fren_dict:
#   for j in fren_dict[i]:
#     for id, k in enumerate(j):
#       for l in frla_dict[i]:
#         for jd, m in enumerate(l):
#           if ((id == jd)):
#             k[1][0].update({
#                 'la_sent_id':m[1][0]['sent_id'],
#                 'la_sent_aligned':m[1][0]['la_sent_aligned']
#             })

# %%
# with open(f'fr_data_stanza.json', 'w', encoding='utf-8') as lang:
#   json.dump(fren_dict, lang, ensure_ascii=False, indent=4)

# %% [markdown]
# # Book-level formatting (by hand) with functions from above

# %%
def chapterParse(fr_chapter_series, en_chapter_series, la_chapter_series): ## takes pandas series of chapter text 
  for i in range(len(fr_chapter_series)):
    print(f'Chapter {i+1}/{len(fr_chapter_series)}')
    fr_chapter = fr_chapter_series[i]
    with open('dev.fr', "w") as frb:
      for line in fr_chapter.split('.'):
        frb.write(line + '.\n')
    en_chapter = en_chapter_series[i]
    with open('dev.en', "w") as erb:
      for line in en_chapter.split('.'):
        erb.write(line + '.\n')
    la_chapter = la_chapter_series[i]
    split_lines = re.findall("[A-Z].+?\.", la_chapter)#############COMEBACK  [f(x) for x in sequence if condition]
    split_lines = [' '.join([split_lines[i], split_lines[i+1]]) if len(split_lines[i].split())<4 else split_lines[i] for i in range(len(split_lines))] 
    with open('dev.la', "w") as enb:
      for line in split_lines:
        enb.write(line + '\n')

    # !/content/vecalign/overlap.py -i /content/dev.fr -o overlaps.fr -n 10
    # !/content/vecalign/overlap.py -i /content/dev.en -o overlaps.en -n 10
    # !/content/vecalign/overlap.py -i /content/dev.la -o overlaps.la -n 10

    with open('/content/overlaps.fr', 'r') as frOver:
      fr_overlap = frOver.readlines() 
    with open('/content/overlaps.en', 'r') as enOver:
      en_overlap = enOver.readlines()
    with open('/content/overlaps.la','r') as laOver:
      la_overlap = laOver.readlines()
      
## Turn on for embeddings
    fr_embeddings = laser.embed_sentences(fr_overlap,lang='fr')
    en_embeddings = laser.embed_sentences(en_overlap,lang='la')
    la_embeddings = laser.embed_sentences(la_overlap,lang='la')

    with open('overlaps.fr.emb','wb') as fEmb:
      for line in fr_embeddings:
        fEmb.write(bytes(line))
    with open('overlaps.en.emb','wb') as eEmb:
      for line in en_embeddings:
        eEmb.write(bytes(line))   
    with open('overlaps.la.emb', 'wb') as lEmb:
      for line in la_embeddings:
        lEmb.write(bytes(line)) 

    old_stdout = sys.stdout

    sys.stdout = open('FrEnVecalignLog.txt','wt')
    # !/content/vecalign/vecalign.py --src /content/dev.fr --tgt /content/dev.en \
    --src_embed /content/overlaps.fr /content/overlaps.fr.emb \
    --tgt_embed /content/overlaps.en /content/overlaps.en.emb
    sys.stdout.close()
    sys.stdout = old_stdout
    with open('/content/FrEnVecalignLog.txt','r') as fren_val:
      fren_vec_log = fren_val.readlines()
    fren_aligned_sent, fren_unaligned, eng_unaligned = createAlignedUnalignedFrEn(fren_vec_log)
    FrEnalignedIndiciesJSON(fren_aligned_sent,i)

    sys.stdout = open('FrLaVecalignLog.txt','wt')
    # !/content/vecalign/vecalign.py --src /content/dev.fr --tgt /content/dev.la \
    --src_embed /content/overlaps.fr /content/overlaps.fr.emb \
    --tgt_embed /content/overlaps.la /content/overlaps.la.emb
    sys.stdout.close()
    sys.stdout = old_stdout
    with open('/content/FrLaVecalignLog.txt','r') as frla_val:
      frla_vec_log = frla_val.readlines()
    frla_aligned_sent, frla_unaligned, lat_unaligned = createAlignedUnalignedFrLa(frla_vec_log)
    FrLaalignedIndiciesJSON(frla_aligned_sent, i)

    with open("dev.fr", "r") as french_read:
      french_sent = french_read.readlines()
    with open("dev.en", "r") as english_read:
      english_sent = english_read.readlines()
    with open("dev.la", "r") as latin_read:
      latin_sent = latin_read.readlines()
    # !mkdir aligned_sentences
    # !mkdir aligned_numbers
    # !mkdir aligned_words

    print("French, French -> English")
    fren_dict = fren_generateJSON(french_sent, fren_unaligned, fren_aligned_sent, i, french_sent, english_sent)
    print("English, French -> English")
    fren_generateJSON(english_sent, eng_unaligned, fren_aligned_sent, i, french_sent, english_sent)

    print("French, French -> Latin")
    frla_dict = frla_generateJSON(french_sent, frla_unaligned, frla_aligned_sent, i, french_sent, latin_sent)
    print("Latin, French -> Latin")
    frla_generateJSON(latin_sent, lat_unaligned, frla_aligned_sent, i, french_sent, latin_sent)

    for n in fren_dict:
      for j in fren_dict[n]:
        for id, k in enumerate(j):
          for l in frla_dict[n]:
            for jd, m in enumerate(l):
              if ((id == jd)):
                k[1][0].update({
                    'la_sent_id':m[1][0]['sent_id'],
                    'la_sent_aligned':m[1][0]['la_sent_aligned']
                })
    with open(f'fr_data_stanza{i}.json', 'w', encoding='utf-8') as lang:
      json.dump(fren_dict, lang, ensure_ascii=False, indent=4)

# %%
fr_book1 = french_df[0][0:10]
en_book1 = english_df[0][0:10]
la_book1 = latin_df[0][0:10]

# %%
chapterParse(fr_book1, en_book1, la_book1)
# Out:
# Chapter 1/10
# mkdir: cannot create directory ‘aligned_sentences’: File exists
# mkdir: cannot create directory ‘aligned_numbers’: File exists
# mkdir: cannot create directory ‘aligned_words’: File exists
# French, French -> English
# mkdir: cannot create directory ‘aligned_sentences’: File exists
# mkdir: cannot create directory ‘aligned_numbers’: File exists
# mkdir: cannot create directory ‘aligned_words’: File exists
# 0/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.91it/s]
# 1/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.73it/s]
# 2/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.77it/s]
# /usr/local/lib/python3.7/dist-packages/stanza/models/common/beam.py:86: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   prevK = bestScoresId // numWords
# 3/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.12it/s]
# 4/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.68it/s]
# 5/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  2.00it/s]
# 6/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.32s/it]
# 7/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.62it/s]
# 8/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.50it/s]
# 9/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.26s/it]
# 101112/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.06s/it]
# 101112/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.12s/it]
# 101112/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.06s/it]
# 13/46 1
# 14/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.52it/s]
# 15/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.69s/it]
# 16/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.66s/it]
# 17/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.12s/it]
# 18/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.46it/s]
# 19/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.34it/s]
# 20/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.35s/it]
# 21/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.04s/it]
# 22/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.67it/s]
# 23/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.24s/it]
# 24/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.35s/it]
# 25/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.81s/it]
# 26/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.03s/it]
# 27/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.01s/it]
# 28/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.06it/s]
# 2930/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.53s/it]
# 2930/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.53s/it]
# 31/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.61s/it]
# 32/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.38it/s]
# 33/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.28s/it]
# 34/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.31it/s]
# 35/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.10it/s]
# 36/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.15it/s]
# 37/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.19s/it]
# 3839/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.02it/s]
# 3839/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.04it/s]
# 40/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.00it/s]
# 41/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.15it/s]
# 42/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.44s/it]
# 43/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.51it/s]
# 44/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.44it/s]
# 45/45
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  2.46it/s]
# English, French -> English
# 0/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.84it/s]
# 1/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.69it/s]
# 2/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.74it/s]
# 3/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.12it/s]
# 4/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.54it/s]
# 5/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.98it/s]
# 67/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.34s/it]
# 67/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.35s/it]
# 8/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.55it/s]
# 9/68 1
# 10/68 1
# 11/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.47it/s]
# 12/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.22s/it]
# 13/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.12s/it]
# 14/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.46it/s]
# 151617/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.76s/it]
# 151617/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.76s/it]
# 151617/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.76s/it]
# 181920/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.72s/it]
# 181920/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.67s/it]
# 181920/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.72s/it]
# 212223/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.08s/it]
# 212223/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.06s/it]
# 212223/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.05s/it]
# 24/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.47it/s]
# 25/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.39it/s]
# 262728/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.41s/it]
# 262728/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.42s/it]
# 262728/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.43s/it]
# 29/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.04s/it]
# 30/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.65it/s]
# 3132/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.24s/it]
# 3132/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.27s/it]
# 3334/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.37s/it]
# 3334/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.37s/it]
# 353637/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.80s/it]
# 353637/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.81s/it]
# 353637/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.81s/it]
# 38/68 1
# 3940/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.03s/it]
# 3940/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.06s/it]
# 4142/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.04s/it]
# 4142/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.01s/it]
# 43/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.07it/s]
# 44/68 1
# 45/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.54s/it]
# 464748/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.62s/it]
# 464748/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.61s/it]
# 464748/67
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:02,  2.61s/it]
# 49/67
# Loading the dataset...
# ...
#   cpuset_checked))
# Extracting: 1it [00:01,  1.35s/it]
# 7475/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.45s/it]
# 7475/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:01,  1.45s/it]
# 76/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.24it/s]
# 7778/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.40it/s]
# 7778/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.43it/s]
# 798081/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.77it/s]
# 798081/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.81it/s]
# 798081/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.85it/s]
# 82/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.87it/s]
# 83/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.21it/s]
# 84/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.74it/s]
# 85/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.67it/s]
# 868788/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.26it/s]
# 868788/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.34it/s]
# 868788/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.31it/s]
# 8990/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.44it/s]
# 8990/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.50it/s]
# 9192/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.14it/s]
# 9192/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.14it/s]
# 939495/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.48it/s]
# 939495/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.50it/s]
# 939495/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.50it/s]
# 96/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.46it/s]
# 97/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.36it/s]
# 98/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.30it/s]
# 99100101/161
# Loading the dataset...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Extracting: 1it [00:00,  1.20it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-05dc596a213a> in <module>()
# ----> 1 chapterParse(fr_book1, en_book1, la_book1)
#
# <ipython-input-56-80a2348ce3d6> in chapterParse(fr_chapter_series, en_chapter_series, la_chapter_series)
#      74
#      75     print("French, French -> English")
# ---> 76     fren_dict = fren_generateJSON(french_sent, fren_unaligned, fren_aligned_sent, i, french_sent, english_sent)
#      77     print("English, French -> English")
#      78     fren_generateJSON(english_sent, eng_unaligned, fren_aligned_sent, i, french_sent, english_sent)
#
# <ipython-input-59-b1b8ff1b52d1> in fren_generateJSON(lang_sent, unaligned, aligned_sent, chapter_number, french_sent, english_sent)
#      29           else:
#      30             if ((type(tup[0]) ==  tuple) and (index in tup[0])):
# ---> 31               x_lang_dict = makeFrEnWordDictionary(tup, french_sent, french_sent, english_sent, aligned_sent, index, chapter_number)
#      32               dict_to_json[index].append(x_lang_dict)
#      33         with open(f'fren_data_stanza{chapter_number}.json', 'w', encoding='utf-8') as lang:
#
# <ipython-input-41-3b35a8a728f2> in makeFrEnWordDictionary(aligned_tup, text, french_sent, english_sent, aligned_sent, unaligned_id, chap_number)
#     104       x_lang_freq[word].append(i)
#     105
# --> 106   x_lang_dict = formatJSONX(x_lang, x_lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)
#     107
#     108   return x_lang_dict
#
# <ipython-input-42-227f3b89dd53> in formatJSONX(lang, lang_freq, align_words, source_text_index, aligned_sent, unaligned_id, tup_type, chap_number)
#      10     if len(re.findall('..', str(source_text_index))) > 1:
#      11       org_tup = tuple([int(n) for n in re.findall('..', str(source_text_index))])
# ---> 12       org_indx = list(zip(*aligned_sent))[0].index(org_tup)
#      13       org_tgt = list(zip(*aligned_sent))[1][org_indx]
#      14       if type(org_tgt) == tuple:
#
# ValueError: tuple.index(x): x not in tuple
